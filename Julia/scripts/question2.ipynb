# %%
import Pkg
using Pkg

# Install required packages
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("StatsModels")
Pkg.add("GLM")
Pkg.add("Random")
Pkg.add("MLDataUtils")
Pkg.add("MLBase")
Pkg.add("FixedEffectModels")
Pkg.add("Lasso")
Pkg.add("MLJ")
Pkg.add("DecisionTree")
Pkg.add("RData")
Pkg.add("GLMNet")
Pkg.add("PrettyTables")
Pkg.add("MLJScikitLearnInterface")
Pkg.add("MLJFlux")
Pkg.add("Flux")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed DataAPI ───────────────────── v1.16.0
#    Installed TableTraits ───────────────── v1.0.1
#    Installed SentinelArrays ────────────── v1.4.8
#    Installed IteratorInterfaceExtensions ─ v1.0.0
#    Installed PooledArrays ──────────────── v1.4.3
#    Installed InlineStrings ─────────────── v1.4.5
#    Installed Tables ────────────────────── v1.12.1
#    Installed CSV ───────────────────────── v0.10.15
#    Installed DataValueInterfaces ───────── v1.0.0
#    Installed WorkerUtilities ───────────── v1.6.1
#    Installed OrderedCollections ────────── v1.8.1
#    Installed FilePathsBase ─────────────── v0.9.24
#    Installed WeakRefStrings ────────────── v1.4.2
#    Installed Compat ────────────────────── v4.18.1
#    Installed TranscodingStreams ────────── v0.11.3
#    Installed CodecZlib ─────────────────── v0.7.8
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [336ed68f] + CSV v0.10.15
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [336ed68f] + CSV v0.10.15
#   [944b1d66] + CodecZlib v0.7.8
#   [34da2185] + Compat v4.18.1
#   [9a962f9c] + DataAPI v1.16.0
#   [e2d170a0] + DataValueInterfaces v1.0.0
#   [48062228] + FilePathsBase v0.9.24
#   [842dd82b] + InlineStrings v1.4.5
#   [82899510] + IteratorInterfaceExtensions v1.0.0
#   [bac558e1] + OrderedCollections v1.8.1
#   [2dfb63ee] + PooledArrays v1.4.3
#   [91c51154] + SentinelArrays v1.4.8
#   [3783bdb8] + TableTraits v1.0.1
#   [bd369af6] + Tables v1.12.1
#   [3bb67fe8] + TranscodingStreams v0.11.3
#   [ea10d353] + WeakRefStrings v1.4.2
#   [76eceee3] + WorkerUtilities v1.6.1
#   [9fa8497b] + Future v1.11.0
# Precompiling project...
#     270.3 ms  ✓ IteratorInterfaceExtensions
#     275.1 ms  ✓ DataValueInterfaces
#     280.9 ms  ✓ DataAPI
#     304.0 ms  ✓ WorkerUtilities
#     348.7 ms  ✓ TranscodingStreams
#     406.7 ms  ✓ OrderedCollections
#     374.9 ms  ✓ Compat
#     426.9 ms  ✓ InlineStrings
#     323.2 ms  ✓ TableTraits
#     639.0 ms  ✓ SentinelArrays
#     490.8 ms  ✓ PooledArrays
#     420.7 ms  ✓ FilePathsBase
#     526.2 ms  ✓ CodecZlib
#     512.6 ms  ✓ InlineStrings → ParsersExt
#     359.2 ms  ✓ FilePathsBase → FilePathsBaseMmapExt
#     562.5 ms  ✓ WeakRefStrings
#     994.9 ms  ✓ Tables
#    5682.5 ms  ✓ CSV
#   18 dependencies successfully precompiled in 8 seconds. 40 already precompiled.
#    Resolving package versions...
#    Installed Reexport ─────────── v1.2.2
#    Installed LaTeXStrings ─────── v1.4.0
#    Installed Crayons ──────────── v4.1.1
#    Installed Statistics ───────── v1.11.1
#    Installed InvertedIndices ──── v1.3.1
#    Installed DataStructures ───── v0.19.3
#    Installed DataFrames ───────── v1.8.1
#    Installed PrettyTables ─────── v3.1.0
#    Installed SortingAlgorithms ── v1.2.2
#    Installed Missings ─────────── v1.2.0
#    Installed StringManipulation ─ v0.4.1
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [a93c6f00] + DataFrames v1.8.1
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [a8cc5b0e] + Crayons v4.1.1
#   [a93c6f00] + DataFrames v1.8.1
#   [864edb3b] + DataStructures v0.19.3
#   [41ab1584] + InvertedIndices v1.3.1
#   [b964fa9f] + LaTeXStrings v1.4.0
#   [e1d29d7a] + Missings v1.2.0
#   [08abe8d2] + PrettyTables v3.1.0
#   [189a3867] + Reexport v1.2.2
#   [a2af1166] + SortingAlgorithms v1.2.2
#   [10745b16] + Statistics v1.11.1
#   [892a3eda] + StringManipulation v0.4.1
#   [37e2e46d] + LinearAlgebra v1.11.0
#   [e66e0078] + CompilerSupportLibraries_jll v1.1.1+0
#   [4536629a] + OpenBLAS_jll v0.3.27+1
#   [8e850b90] + libblastrampoline_jll v5.11.0+0
# Precompiling project...
#     234.1 ms  ✓ LaTeXStrings
#     216.4 ms  ✓ Reexport
#     231.6 ms  ✓ InvertedIndices
#     262.6 ms  ✓ Missings
#     298.7 ms  ✓ Statistics
#     338.4 ms  ✓ Compat → CompatLinearAlgebraExt
#     524.5 ms  ✓ Crayons
#     736.7 ms  ✓ StringManipulation
#     917.9 ms  ✓ DataStructures
#     424.7 ms  ✓ SortingAlgorithms
#   11057.5 ms  ✓ PrettyTables
#   16892.1 ms  ✓ DataFrames
#   12 dependencies successfully precompiled in 29 seconds. 59 already precompiled.
#    Resolving package versions...
#    Installed Rmath_jll ─────────────── v0.5.1+0
#    Installed Rmath ─────────────────── v0.9.0
#    Installed PtrArrays ─────────────── v1.3.0
#    Installed IrrationalConstants ───── v0.2.6
#    Installed StatsFuns ─────────────── v1.5.2
#    Installed HypergeometricFunctions ─ v0.3.28
#    Installed StatsModels ───────────── v0.7.7
#    Installed SpecialFunctions ──────── v2.6.1
#    Installed OpenSpecFun_jll ───────── v0.5.6+0
#    Installed StatsAPI ──────────────── v1.7.1
#    Installed ShiftedArrays ─────────── v2.0.0
#    Installed AliasTables ───────────── v1.1.3
#    Installed LogExpFunctions ───────── v0.3.29
#    Installed DocStringExtensions ───── v0.9.5
#    Installed StatsBase ─────────────── v0.34.8
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [3eaba693] + StatsModels v0.7.7
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [66dad0bd] + AliasTables v1.1.3
#   [ffbed154] + DocStringExtensions v0.9.5
#   [34004b35] + HypergeometricFunctions v0.3.28
#   [92d709cd] + IrrationalConstants v0.2.6
#   [2ab3a3ac] + LogExpFunctions v0.3.29
#   [43287f4e] + PtrArrays v1.3.0
#   [79098fc4] + Rmath v0.9.0
#   [1277b4bf] + ShiftedArrays v2.0.0
#   [276daf66] + SpecialFunctions v2.6.1
#   [82ae8749] + StatsAPI v1.7.1
#   [2913bbd2] + StatsBase v0.34.8
#   [4c63d2b9] + StatsFuns v1.5.2
#   [3eaba693] + StatsModels v0.7.7
#   [efe28fd5] + OpenSpecFun_jll v0.5.6+0
#   [f50d1b31] + Rmath_jll v0.5.1+0
#   [9e88b42a] + Serialization v1.11.0
#   [2f01184e] + SparseArrays v1.11.0
#   [05823500] + OpenLibm_jll v0.8.5+0
#   [bea87d4a] + SuiteSparse_jll v7.7.0+0
# Precompiling project...
#     221.4 ms  ✓ PtrArrays
#     233.7 ms  ✓ ShiftedArrays
#     241.0 ms  ✓ StatsAPI
#     320.7 ms  ✓ DocStringExtensions
#     302.9 ms  ✓ Rmath_jll
#     328.6 ms  ✓ OpenSpecFun_jll
#     367.8 ms  ✓ Statistics → SparseArraysExt
#     522.1 ms  ✓ IrrationalConstants
#     376.6 ms  ✓ AliasTables
#     599.1 ms  ✓ Rmath
#     544.1 ms  ✓ LogExpFunctions
#    1416.9 ms  ✓ SpecialFunctions
#    1696.6 ms  ✓ StatsBase
#     594.6 ms  ✓ HypergeometricFunctions
#     875.0 ms  ✓ StatsFuns
#    1363.0 ms  ✓ StatsModels
#   16 dependencies successfully precompiled in 5 seconds. 75 already precompiled.
#    Resolving package versions...
#    Installed PDMats ──────── v0.11.36
#    Installed QuadGK ──────── v2.11.2
#    Installed GLM ─────────── v1.9.0
#    Installed FillArrays ──── v1.15.0
#    Installed Distributions ─ v0.25.122
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [38e38edf] + GLM v1.9.0
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [31c24e10] + Distributions v0.25.122
#   [1a297f60] + FillArrays v1.15.0
#   [38e38edf] + GLM v1.9.0
#   [90014a1f] + PDMats v0.11.36
#   [1fd47b50] + QuadGK v2.11.2
#   [4607b0f0] + SuiteSparse
# Precompiling project...
#     263.8 ms  ✓ SuiteSparse
#     469.0 ms  ✓ FillArrays
#     423.2 ms  ✓ QuadGK
#    1195.9 ms  ✓ PDMats
#    1764.6 ms  ✓ FillArrays → FillArraysStatisticsExt
#    1770.9 ms  ✓ FillArrays → FillArraysSparseArraysExt
#    1474.6 ms  ✓ FillArrays → FillArraysPDMatsExt
#    1512.2 ms  ✓ PDMats → StatsBaseExt
#    2797.3 ms  ✓ Distributions
#    1348.7 ms  ✓ GLM
#   10 dependencies successfully precompiled in 7 seconds. 91 already precompiled.
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [9a3f8284] + Random v1.11.0
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#    Installed DataStructures ─ v0.18.22
#    Installed PDMats ───────── v0.11.35
#    Installed LearnBase ────── v0.3.0
#    Installed Conda ────────── v1.10.3
#    Installed DelimitedFiles ─ v1.9.1
#    Installed ZMQ ──────────── v1.5.1
#    Installed JSON ─────────── v1.2.1
#    Installed MLDataPattern ── v0.5.4
#    Installed MappedArrays ─── v0.4.2
#    Installed StatsBase ────── v0.33.21
#    Installed StructUtils ──── v2.6.0
#    Installed MLDataUtils ──── v0.5.4
#    Installed MLLabelUtils ─── v0.5.7
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [cc2ba9b6] + MLDataUtils v0.5.4
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [8f4d0f93] ↑ Conda v1.10.2 ⇒ v1.10.3
# ⌅ [864edb3b] ↓ DataStructures v0.19.3 ⇒ v0.18.22
#   [8bb1440f] + DelimitedFiles v1.9.1
#   [682c06a0] ↑ JSON v0.21.4 ⇒ v1.2.1
# ⌅ [7f8f8fb0] + LearnBase v0.3.0
# ⌃ [9920b226] + MLDataPattern v0.5.4
#   [cc2ba9b6] + MLDataUtils v0.5.4
#   [66a33bbf] + MLLabelUtils v0.5.7
#   [dbb5928d] + MappedArrays v0.4.2
# ⌃ [90014a1f] ↓ PDMats v0.11.36 ⇒ v0.11.35
# ⌅ [2913bbd2] ↓ StatsBase v0.34.8 ⇒ v0.33.21
#   [ec057cc2] + StructUtils v2.6.0
#   [c2297ded] ↑ ZMQ v1.5.0 ⇒ v1.5.1
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
#     Building Conda → `~/.julia/scratchspaces/44cfe95a-1eb2-52ea-b672-e2afdf69b78f/8f06b0cfa4c514c7b9546756dbae91fcfbc92dc9/build.log`
# Precompiling project...
#     225.2 ms  ✓ MappedArrays
#     244.4 ms  ✓ DelimitedFiles
#     373.4 ms  ✓ StructUtils
#     415.9 ms  ✓ PDMats
#     331.7 ms  ✓ StructUtils → StructUtilsTablesExt
#     870.2 ms  ✓ DataStructures
#     534.6 ms  ✓ FillArrays → FillArraysPDMatsExt
#    1021.1 ms  ✓ ZMQ
#     415.3 ms  ✓ SortingAlgorithms
#     619.1 ms  ✓ QuadGK
#    1394.7 ms  ✓ JSON
#     540.2 ms  ✓ Conda
#    1106.4 ms  ✓ StatsBase
#     494.3 ms  ✓ LearnBase
#    1133.2 ms  ✓ StatsModels
#     680.2 ms  ✓ MLLabelUtils
#     713.0 ms  ✓ MLDataPattern
#    2688.6 ms  ✓ Distributions
#    1286.7 ms  ✓ GLM
#   16600.2 ms  ✓ DataFrames
#    1589.1 ms  ✓ MLDataUtils
#   21 dependencies successfully precompiled in 20 seconds. 87 already precompiled.
#   3 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions. Otherwise, loading dependents of these packages may trigger further precompilation to work with the unexpected versions.
#    Resolving package versions...
#    Installed MLBase ──── v0.9.2
#    Installed IterTools ─ v1.10.0
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [f0e99cf1] + MLBase v0.9.2
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [c8e1da08] + IterTools v1.10.0
#   [f0e99cf1] + MLBase v0.9.2
# Precompiling project...
#     262.5 ms  ✓ IterTools
#     616.5 ms  ✓ MLBase
#   2 dependencies successfully precompiled in 1 seconds. 108 already precompiled.
#    Resolving package versions...
#    Installed GroupedArrays ───── v0.3.4
#    Installed Vcov ────────────── v0.8.1
#    Installed Combinatorics ───── v1.0.3
#    Installed FixedEffects ────── v2.4.1
#    Installed FixedEffectModels ─ v1.12.0
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [9d5cd8c9] + FixedEffectModels v1.12.0
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [861a8166] + Combinatorics v1.0.3
#   [9d5cd8c9] + FixedEffectModels v1.12.0
#   [c8885935] + FixedEffects v2.4.1
#   [6407cd72] + GroupedArrays v0.3.4
#   [ec2bfdc2] + Vcov v0.8.1
# Precompiling project...
#     291.5 ms  ✓ GroupedArrays
#     391.7 ms  ✓ Combinatorics
#    1739.2 ms  ✓ FixedEffects
#    5958.5 ms  ✓ Vcov
#    8115.2 ms  ✓ FixedEffectModels
#   5 dependencies successfully precompiled in 15 seconds. 110 already precompiled.
#    Resolving package versions...
#    Installed AbstractFFTs ───── v1.5.0
#    Installed FFTW ───────────── v1.10.0
#    Installed oneTBB_jll ─────── v2022.0.0+1
#    Installed Setfield ───────── v1.1.2
#    Installed MKL_jll ────────── v2025.2.0+0
#    Installed RecipesBase ────── v1.3.4
#    Installed Bessels ────────── v0.2.8
#    Installed DSP ────────────── v0.8.4
#    Installed StaticArraysCore ─ v1.4.4
#    Installed ConstructionBase ─ v1.6.0
#    Installed FFTW_jll ───────── v3.3.11+0
#    Installed IntelOpenMP_jll ── v2025.2.0+0
#    Installed Requires ───────── v1.3.1
#    Installed Lasso ──────────── v0.7.3
#    Installed MacroTools ─────── v0.5.16
#    Installed Polynomials ────── v4.1.0
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [b4fcebef] + Lasso v0.7.3
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [621f4979] + AbstractFFTs v1.5.0
#   [0e736298] + Bessels v0.2.8
#   [187b0558] + ConstructionBase v1.6.0
#   [717857b8] + DSP v0.8.4
#   [7a1cc6ca] + FFTW v1.10.0
#   [b4fcebef] + Lasso v0.7.3
#   [1914dd2f] + MacroTools v0.5.16
#   [f27b6e38] + Polynomials v4.1.0
#   [3cdcf5f2] + RecipesBase v1.3.4
#   [ae029012] + Requires v1.3.1
#   [efcf1570] + Setfield v1.1.2
#   [1e83bf80] + StaticArraysCore v1.4.4
#   [f5851436] + FFTW_jll v3.3.11+0
#   [1d5cc7b8] + IntelOpenMP_jll v2025.2.0+0
#   [856f044c] + MKL_jll v2025.2.0+0
#   [1317d2d5] + oneTBB_jll v2022.0.0+1
#   [4af54fe1] + LazyArtifacts v1.11.0
# Precompiling project...
#     307.3 ms  ✓ StaticArraysCore
#     308.5 ms  ✓ ConstructionBase
#     342.0 ms  ✓ Requires
#     367.5 ms  ✓ FFTW_jll
#     371.8 ms  ✓ AbstractFFTs
#     373.6 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#     732.0 ms  ✓ oneTBB_jll
#     777.9 ms  ✓ RecipesBase
#     822.9 ms  ✓ Bessels
#     547.1 ms  ✓ IntelOpenMP_jll
#    1033.5 ms  ✓ MacroTools
#     484.3 ms  ✓ MKL_jll
#     852.2 ms  ✓ Setfield
#    3307.1 ms  ✓ FFTW
#    7556.6 ms  ✓ Polynomials
#     913.4 ms  ✓ Polynomials → PolynomialsFFTWExt
#    1604.7 ms  ✓ DSP
#    1604.5 ms  ✓ Lasso
#   18 dependencies successfully precompiled in 14 seconds. 116 already precompiled.
#    Resolving package versions...
#    Installed StatisticalTraits ──────── v3.5.0
#    Installed CategoricalDistributions ─ v0.1.15
#    Installed RelocatableFolders ─────── v1.0.1
#    Installed LoggingExtras ──────────── v1.2.0
#    Installed Accessors ──────────────── v0.1.42
#    Installed NNlib ──────────────────── v0.9.31
#    Installed ContextVariablesX ──────── v0.1.3
#    Installed ShowCases ──────────────── v0.1.0
#    Installed ConcurrentUtilities ────── v2.5.0
#    Installed ProgressMeter ──────────── v1.11.0
#    Installed ScopedValues ───────────── v1.5.0
#    Installed OpenSSL ────────────────── v1.6.0
#    Installed EarlyStopping ──────────── v0.3.0
#    Installed InitialValues ──────────── v0.3.1
#    Installed StaticArrays ───────────── v1.9.15
#    Installed LearnAPI ───────────────── v0.1.0
#    Installed MLUtils ────────────────── v0.4.8
#    Installed MLCore ─────────────────── v1.0.0
#    Installed MLJModels ──────────────── v0.16.17
#    Installed IterationControl ───────── v0.5.4
#    Installed HTTP ───────────────────── v1.10.19
#    Installed PrettyPrint ────────────── v0.2.0
#    Installed MLJIteration ───────────── v0.6.4
#    Installed Distances ──────────────── v0.10.12
#    Installed SimpleBufferStream ─────── v1.2.0
#    Installed MicroCollections ───────── v0.2.0
#    Installed DefineSingletons ───────── v0.1.2
#    Installed StatisticalMeasures ────── v0.1.7
#    Installed MLJBase ────────────────── v1.7.0
#    Installed FLoopsBase ─────────────── v0.1.1
#    Installed MLJFlow ────────────────── v0.2.0
#    Installed MLStyle ────────────────── v0.4.17
#    Installed NameResolution ─────────── v0.1.5
#    Installed ComputationalResources ─── v0.3.2
#    Installed MbedTLS ────────────────── v1.1.9
#    Installed PrettyPrinting ─────────── v0.4.2
#    Installed BangBang ───────────────── v0.4.6
#    Installed FLoops ─────────────────── v0.2.2
#    Installed ExceptionUnwrapping ────── v0.1.11
#    Installed ColorTypes ─────────────── v0.12.1
#    Installed Scratch ────────────────── v1.3.0
#    Installed MLJ ────────────────────── v0.20.0
#    Installed StatisticalMeasuresBase ── v0.1.3
#    Installed ArgCheck ───────────────── v2.5.0
#    Installed CategoricalArrays ──────── v0.10.8
#    Installed PrettyTables ───────────── v2.4.0
#    Installed ARFFFiles ──────────────── v1.5.0
#    Installed HashArrayMappedTries ───── v0.2.0
#    Installed ScientificTypes ────────── v3.1.1
#    Installed OpenML ─────────────────── v0.3.2
#    Installed ChainRulesCore ─────────── v1.26.0
#    Installed UnPack ─────────────────── v1.0.2
#    Installed CompositionsBase ───────── v0.1.2
#    Installed KernelAbstractions ─────── v0.9.39
#    Installed JuliaVariables ─────────── v0.2.4
#    Installed InverseFunctions ───────── v0.1.17
#    Installed UnsafeAtomics ──────────── v0.3.0
#    Installed SimpleTraits ───────────── v0.9.5
#    Installed GPUArraysCore ──────────── v0.2.0
#    Installed LatinHypercubeSampling ─── v1.9.0
#    Installed Atomix ─────────────────── v1.1.2
#    Installed Transducers ────────────── v0.4.85
#    Installed ScientificTypesBase ────── v3.0.0
#    Installed MLJEnsembles ───────────── v0.4.3
#    Installed MLJTuning ──────────────── v0.8.8
#    Installed FixedPointNumbers ──────── v0.8.5
#    Installed Adapt ──────────────────── v4.4.0
#    Installed StableRNGs ─────────────── v1.0.4
#    Installed MLJModelInterface ──────── v1.12.0
#    Installed OpenSSL_jll ────────────── v3.5.4+0
#    Installed BitFlags ───────────────── v0.1.9
#    Installed Baselet ────────────────── v0.1.1
#    Installed MLFlowClient ───────────── v0.4.7
#    Installed URIs ───────────────────── v1.6.1
#    Installed Parameters ─────────────── v0.12.3
#    Installed SplittablesBase ────────── v0.1.15
#     Updating `~/.julia/environments/v1.11/Project.toml`
# ⌃ [add582a8] + MLJ v0.20.0
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [da404889] + ARFFFiles v1.5.0
#   [7d9f7c33] + Accessors v0.1.42
#   [79e6a3ab] + Adapt v4.4.0
#   [dce04be8] + ArgCheck v2.5.0
#   [a9b6321e] + Atomix v1.1.2
#   [198e06fe] + BangBang v0.4.6
#   [9718e550] + Baselet v0.1.1
#   [d1d4a3ce] + BitFlags v0.1.9
# ⌅ [324d7699] + CategoricalArrays v0.10.8
# ⌅ [af321ab8] + CategoricalDistributions v0.1.15
#   [d360d2e6] + ChainRulesCore v1.26.0
#   [3da002f7] + ColorTypes v0.12.1
#   [a33af91c] + CompositionsBase v0.1.2
#   [ed09eef8] + ComputationalResources v0.3.2
#   [f0e56b4a] + ConcurrentUtilities v2.5.0
#   [6add18c4] + ContextVariablesX v0.1.3
#   [244e2a9f] + DefineSingletons v0.1.2
#   [b4f34e82] + Distances v0.10.12
#   [792122b4] + EarlyStopping v0.3.0
#   [460bff9d] + ExceptionUnwrapping v0.1.11
#   [cc61a311] + FLoops v0.2.2
#   [b9860ae5] + FLoopsBase v0.1.1
#   [53c48c17] + FixedPointNumbers v0.8.5
#   [46192b85] + GPUArraysCore v0.2.0
#   [cd3eb016] + HTTP v1.10.19
#   [076d061b] + HashArrayMappedTries v0.2.0
#   [22cec73e] + InitialValues v0.3.1
#   [3587e190] + InverseFunctions v0.1.17
#   [b3c1a2ee] + IterationControl v0.5.4
# ⌅ [682c06a0] ↓ JSON v1.2.1 ⇒ v0.21.4
#   [b14d175d] + JuliaVariables v0.2.4
#   [63c18a36] + KernelAbstractions v0.9.39
#   [a5e1c1ea] + LatinHypercubeSampling v1.9.0
# ⌅ [92ad9a40] + LearnAPI v0.1.0
#   [e6f89c97] + LoggingExtras v1.2.0
#   [c2834f40] + MLCore v1.0.0
# ⌅ [64a0f543] + MLFlowClient v0.4.7
# ⌃ [add582a8] + MLJ v0.20.0
# ⌃ [a7f614a8] + MLJBase v1.7.0
# ⌃ [50ed68f4] + MLJEnsembles v0.4.3
# ⌅ [7b7b8358] + MLJFlow v0.2.0
#   [614be32b] + MLJIteration v0.6.4
#   [e80e1ace] + MLJModelInterface v1.12.0
# ⌅ [d491faf4] + MLJModels v0.16.17
#   [03970b2e] + MLJTuning v0.8.8
#   [d8e11817] + MLStyle v0.4.17
#   [f1d291b0] + MLUtils v0.4.8
#   [739be429] + MbedTLS v1.1.9
#   [128add7d] + MicroCollections v0.2.0
#   [872c559c] + NNlib v0.9.31
#   [71a1bf82] + NameResolution v0.1.5
#   [8b6db2d4] + OpenML v0.3.2
#   [4d8831e6] + OpenSSL v1.6.0
#   [d96e819e] + Parameters v0.12.3
#   [8162dcfd] + PrettyPrint v0.2.0
#   [54e16d92] + PrettyPrinting v0.4.2
# ⌅ [08abe8d2] ↓ PrettyTables v3.1.0 ⇒ v2.4.0
#   [92933f4c] + ProgressMeter v1.11.0
#   [05181044] + RelocatableFolders v1.0.1
#   [321657f4] + ScientificTypes v3.1.1
#   [30f210dd] + ScientificTypesBase v3.0.0
#   [7e506255] + ScopedValues v1.5.0
#   [6c6a2e73] + Scratch v1.3.0
#   [605ecd9f] + ShowCases v0.1.0
#   [777ac1f9] + SimpleBufferStream v1.2.0
#   [699a6c99] + SimpleTraits v0.9.5
#   [171d559e] + SplittablesBase v0.1.15
#   [860ef19b] + StableRNGs v1.0.4
#   [90137ffa] + StaticArrays v1.9.15
# ⌅ [a19d573c] + StatisticalMeasures v0.1.7
#   [c062fc1d] + StatisticalMeasuresBase v0.1.3
#   [64bff920] + StatisticalTraits v3.5.0
#   [ec057cc2] - StructUtils v2.6.0
#   [28d57a85] + Transducers v0.4.85
#   [5c2747f8] + URIs v1.6.1
#   [3a884ed6] + UnPack v1.0.2
#   [013be700] + UnsafeAtomics v0.3.0
#   [458c3c95] + OpenSSL_jll v3.5.4+0
#   [8ba89e20] + Distributed v1.11.0
#   [8dfed614] + Test v1.11.0
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     228.6 ms  ✓ UnPack
#     242.8 ms  ✓ ScientificTypesBase
#     243.5 ms  ✓ PrettyPrint
#     256.4 ms  ✓ ArgCheck
#     283.2 ms  ✓ InverseFunctions
#     287.8 ms  ✓ ShowCases
#     456.2 ms  ✓ InitialValues
#     261.1 ms  ✓ StableRNGs
#     248.3 ms  ✓ SimpleBufferStream
#     232.4 ms  ✓ CompositionsBase
#     255.4 ms  ✓ HashArrayMappedTries
#     362.6 ms  ✓ URIs
#     433.6 ms  ✓ Distances
#     231.8 ms  ✓ DefineSingletons
#     271.3 ms  ✓ BitFlags
#     290.6 ms  ✓ Adapt
#     319.2 ms  ✓ ComputationalResources
#    1079.9 ms  ✓ UnsafeAtomics
#     490.3 ms  ✓ ConcurrentUtilities
#     649.8 ms  ✓ Baselet
#    1297.8 ms  ✓ PrettyPrinting
#     524.7 ms  ✓ ProgressMeter
#     355.7 ms  ✓ EarlyStopping
#     299.0 ms  ✓ Scratch
#     669.6 ms  ✓ MbedTLS
#     356.3 ms  ✓ LoggingExtras
#     405.2 ms  ✓ SimpleTraits
#     305.8 ms  ✓ ContextVariablesX
#    1221.3 ms  ✓ FixedPointNumbers
#     335.1 ms  ✓ ExceptionUnwrapping
#     699.8 ms  ✓ LearnAPI
#    1212.6 ms  ✓ CategoricalArrays
#     372.7 ms  ✓ OpenSSL_jll
#     738.5 ms  ✓ ChainRulesCore
#     523.1 ms  ✓ SplittablesBase
#     709.0 ms  ✓ AbstractFFTs → AbstractFFTsTestExt
#     418.2 ms  ✓ Parameters
#     602.6 ms  ✓ FilePathsBase → FilePathsBaseTestExt
#     746.1 ms  ✓ JSON
#     503.3 ms  ✓ NameResolution
#     639.7 ms  ✓ Distributions → DistributionsTestExt
#     598.7 ms  ✓ StatisticalTraits
#     392.6 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#     272.9 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#     435.4 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#     333.7 ms  ✓ StatsFuns → StatsFunsInverseFunctionsExt
#     372.1 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#     220.2 ms  ✓ ScopedValues
#     488.6 ms  ✓ LatinHypercubeSampling
#     470.8 ms  ✓ Distances → DistancesSparseArraysExt
#     440.7 ms  ✓ GPUArraysCore
#     548.6 ms  ✓ Adapt → AdaptSparseArraysExt
#     451.9 ms  ✓ Atomix
#     552.7 ms  ✓ RelocatableFolders
#     608.1 ms  ✓ MLCore
#     886.1 ms  ✓ IterationControl
#     593.3 ms  ✓ FLoopsBase
#     280.6 ms  ✓ CategoricalArrays → CategoricalArraysSentinelArraysExt
#     639.4 ms  ✓ CategoricalArrays → CategoricalArraysRecipesBaseExt
#     277.3 ms  ✓ AbstractFFTs → AbstractFFTsChainRulesCoreExt
#    1111.7 ms  ✓ ColorTypes
#     579.0 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#    1203.2 ms  ✓ ARFFFiles
#     708.4 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#     613.8 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#    3442.6 ms  ✓ StaticArrays
#     298.5 ms  ✓ Distances → DistancesChainRulesCoreExt
#     773.3 ms  ✓ StatsFuns → StatsFunsChainRulesCoreExt
#     865.0 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#     668.2 ms  ✓ Distributions → DistributionsChainRulesCoreExt
#    1553.5 ms  ✓ OpenSSL
#     390.2 ms  ✓ CategoricalArrays → CategoricalArraysJSONExt
#     632.1 ms  ✓ Conda
#     646.1 ms  ✓ ColorTypes → StyledStringsExt
#     741.4 ms  ✓ MLJModelInterface
#     623.5 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#     702.6 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#     433.7 ms  ✓ Adapt → AdaptStaticArraysExt
#     851.5 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    1464.9 ms  ✓ Accessors
#    6764.1 ms  ✓ MLStyle
#     439.9 ms  ✓ Accessors → LinearAlgebraExt
#     463.1 ms  ✓ Accessors → TestExt
#     469.7 ms  ✓ Accessors → StaticArraysExt
#     801.6 ms  ✓ BangBang
#    2066.0 ms  ✓ KernelAbstractions
#     477.9 ms  ✓ BangBang → BangBangTablesExt
#     491.5 ms  ✓ BangBang → BangBangChainRulesCoreExt
#    1422.2 ms  ✓ JuliaVariables
#     492.7 ms  ✓ MicroCollections
#     606.5 ms  ✓ BangBang → BangBangStaticArraysExt
#     551.5 ms  ✓ KernelAbstractions → LinearAlgebraExt
#     632.3 ms  ✓ KernelAbstractions → SparseArraysExt
#    7487.9 ms  ✓ PrettyTables
#    1353.6 ms  ✓ ScientificTypes
#    2754.7 ms  ✓ Transducers
#    1164.8 ms  ✓ CategoricalDistributions
#     546.1 ms  ✓ Transducers → TransducersAdaptExt
#    3395.3 ms  ✓ NNlib
#     597.2 ms  ✓ NNlib → NNlibFFTWExt
#     609.7 ms  ✓ NNlib → NNlibSpecialFunctionsExt
#    1693.6 ms  ✓ FLoops
#    8222.5 ms  ✓ HTTP
#     802.4 ms  ✓ MLFlowClient
#    1534.1 ms  ✓ OpenML
#    4750.7 ms  ✓ MLJModels
#    4490.2 ms  ✓ MLUtils
#    2729.2 ms  ✓ StatisticalMeasuresBase
#    2501.6 ms  ✓ MLJEnsembles
#    3726.3 ms  ✓ MLJBase
#   15962.2 ms  ✓ DataFrames
#    2177.6 ms  ✓ MLJFlow
#    2291.0 ms  ✓ MLJTuning
#     996.3 ms  ✓ Transducers → TransducersDataFramesExt
#    1144.7 ms  ✓ MLDataUtils
#    1158.3 ms  ✓ BangBang → BangBangDataFramesExt
#    2716.7 ms  ✓ MLJIteration
#    7691.1 ms  ✓ StatisticalMeasures
#    1255.4 ms  ✓ StatisticalMeasures → ScientificTypesExt
#    1290.0 ms  ✓ MLJBase → DefaultMeasuresExt
#    3313.5 ms  ✓ MLJ
#    8714.4 ms  ✓ FixedEffectModels
#   122 dependencies successfully precompiled in 34 seconds. 128 already precompiled.
#   2 dependencies precompiled but different versions are currently loaded. Restart julia to access the new versions. Otherwise, loading dependents of these packages may trigger further precompilation to work with the unexpected versions.
#    Resolving package versions...
#    Installed AbstractTrees ─── v0.4.5
#    Installed ScikitLearnBase ─ v0.5.0
#    Installed DecisionTree ──── v0.12.4
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [7806a523] + DecisionTree v0.12.4
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [1520ce14] + AbstractTrees v0.4.5
#   [7806a523] + DecisionTree v0.12.4
#   [6e75b9c4] + ScikitLearnBase v0.5.0
# Precompiling project...
#     285.7 ms  ✓ AbstractTrees
#     259.0 ms  ✓ ScikitLearnBase
#     807.2 ms  ✓ DecisionTree
#   3 dependencies successfully precompiled in 1 seconds. 250 already precompiled.
#    Resolving package versions...
#    Installed TZJData ─── v1.5.0+2025b
#    Installed RData ───── v1.1.0
#    Installed ExprTools ─ v0.1.10
#    Installed Mocking ─── v0.8.1
#    Installed TimeZones ─ v1.22.1
#    Installed FileIO ──── v1.17.1
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [df47a6cb] + RData v1.1.0
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [e2ba6199] + ExprTools v0.1.10
#   [5789e2e9] + FileIO v1.17.1
#   [78c3b35d] + Mocking v0.8.1
#   [df47a6cb] + RData v1.1.0
#   [dc5dba14] + TZJData v1.5.0+2025b
#   [f269a46b] + TimeZones v1.22.1
# Precompiling project...
#     217.5 ms  ✓ ExprTools
#     222.9 ms  ✓ TZJData
#     374.2 ms  ✓ Mocking
#    1727.7 ms  ✓ FileIO
#     771.2 ms  ✓ FileIO → HTTPExt
#    2297.0 ms  ✓ TimeZones
#     444.6 ms  ✓ TimeZones → TimeZonesRecipesBaseExt
#    2035.0 ms  ✓ RData
#   8 dependencies successfully precompiled in 5 seconds. 253 already precompiled.
#    Resolving package versions...
#    Installed glmnet_jll ─ v2.0.13+0
#    Installed GLMNet ───── v0.7.4
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [8d5ece8b] + GLMNet v0.7.4
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [8d5ece8b] + GLMNet v0.7.4
# ⌅ [78c6b45d] + glmnet_jll v2.0.13+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     271.5 ms  ✓ glmnet_jll
#    1205.0 ms  ✓ GLMNet
#   2 dependencies successfully precompiled in 2 seconds. 261 already precompiled.
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.11/Project.toml`
# ⌅ [08abe8d2] + PrettyTables v2.4.0
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`
#    Resolving package versions...
#    Installed StructTypes ───────────── v1.11.0
#    Installed JSON3 ─────────────────── v1.14.3
#    Installed Pidfile ───────────────── v1.3.0
#    Installed micromamba_jll ────────── v1.5.12+0
#    Installed UnsafePointers ────────── v1.0.0
#    Installed CondaPkg ──────────────── v0.2.33
#    Installed MLJScikitLearnInterface ─ v0.7.0
#    Installed PythonCall ────────────── v0.9.28
#    Installed MicroMamba ────────────── v0.1.14
#    Installed pixi_jll ──────────────── v0.41.3+0
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [5ae90465] + MLJScikitLearnInterface v0.7.0
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [992eb4ea] + CondaPkg v0.2.33
#   [0f8b85d8] + JSON3 v1.14.3
#   [5ae90465] + MLJScikitLearnInterface v0.7.0
#   [0b3b1443] + MicroMamba v0.1.14
#   [fa939f87] + Pidfile v1.3.0
#   [6099a3de] + PythonCall v0.9.28
#   [856f2bd8] + StructTypes v1.11.0
#   [e17b2a0c] + UnsafePointers v1.0.0
# ⌅ [f8abcde7] + micromamba_jll v1.5.12+0
#   [4d7b5844] + pixi_jll v0.41.3+0
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     242.1 ms  ✓ UnsafePointers
#     233.3 ms  ✓ Pidfile
#     429.9 ms  ✓ StructTypes
#     546.8 ms  ✓ micromamba_jll
#     545.9 ms  ✓ pixi_jll
#     481.1 ms  ✓ CategoricalArrays → CategoricalArraysStructTypesExt
#    2373.4 ms  ✓ MicroMamba
#    2863.4 ms  ✓ JSON3
#    4657.1 ms  ✓ CondaPkg
#    5339.1 ms  ✓ PythonCall
# CategoricalArraysExt Waiting for background task / IO / timer.
# [pid 57637] waiting for IO to finish:
#  Handle type        uv_handle_t->data
#  timer              0x1063284a0->0x10ebe5ff0
# This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
#   15249.2 ms  ✓ MLJScikitLearnInterface
#   21495.0 ms  ✓ PythonCall → CategoricalArraysExt
#   12 dependencies successfully precompiled in 35 seconds. 263 already precompiled.
#   4 dependencies had output during precompilation:
# ┌ MicroMamba
# │   Downloading artifact: micromamba
# └
# ┌ CondaPkg
# │   Downloading artifact: pixi
# └
# ┌ PythonCall → CategoricalArraysExt
# │  ┌ Info: CondaPkg: Waiting for lock to be freed. You may delete this file if no other process is resolving.
# │  └   lock_file = "/Users/diegosaavedra/.julia/environments/v1.11/.CondaPkg/lock"
# │
# │  [pid 57637] waiting for IO to finish:
# │   Handle type        uv_handle_t->data
# │   timer              0x1063284a0->0x10ebe5ff0
# │  This means that a package has started a background task or event source that has not finished running. For precompilation to complete successfully, the event source needs to be closed explicitly. See the developer documentation on fixing precompilation hangs for more help.
# └
# ┌ MLJScikitLearnInterface
# │      CondaPkg Found dependencies: /Users/diegosaavedra/.julia/packages/MLJScikitLearnInterface/xHP4R/CondaPkg.toml
# │      CondaPkg Found dependencies: /Users/diegosaavedra/.julia/packages/CondaPkg/0UqYV/CondaPkg.toml
# │      CondaPkg Found dependencies: /Users/diegosaavedra/.julia/packages/PythonCall/mkWc2/CondaPkg.toml
# │      CondaPkg Found dependencies: /Users/diegosaavedra/.julia/packages/IJulia/GFGaR/CondaPkg.toml
# │      CondaPkg Resolving changes
# │               + jupyter_client
# │               + jupyter_kernel_test
# │               + openssl
# │               + python
# │               + scikit-learn
# │      CondaPkg Initialising pixi
# │               │ /Users/diegosaavedra/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
# │               │ init
# │               │ --format pixi
# │               └ /Users/diegosaavedra/.julia/environments/v1.11/.CondaPkg
# │  ✔ Created /Users/diegosaavedra/.julia/environments/v1.11/.CondaPkg/pixi.toml
# │      CondaPkg Wrote /Users/diegosaavedra/.julia/environments/v1.11/.CondaPkg/pixi.toml
# │               │ [dependencies]
# │               │ openssl = ">=3, <3.6"
# │               │ jupyter_kernel_test = "*"
# │               │ jupyter_client = "*"
# │               │
# │               │     [dependencies.scikit-learn]
# │               │     channel = "conda-forge"
# │               │     version = ">=1.4, <1.6"
# │               │
# │               │     [dependencies.python]
# │               │     channel = "conda-forge"
# │               │     build = "*cp*"
# │               │     version = ">=3.9,<4"
# │               │
# │               │ [project]
# │               │ name = ".CondaPkg"
# │               │ platforms = ["osx-arm64"]
# │               │ channels = ["conda-forge"]
# │               │ channel-priority = "strict"
# │               └ description = "automatically generated by CondaPkg.jl"
# │      CondaPkg Installing packages
# │               │ /Users/diegosaavedra/.julia/artifacts/d2fecc2a9fa3eac2108d3e4d9d155e6ff5dfd0b2/bin/pixi
# │               │ install
# │               └ --manifest-path /Users/diegosaavedra/.julia/environments/v1.11/.CondaPkg/pixi.toml
# │  ✔ The default environment has been installed.
# └
#    Resolving package versions...
#    Installed SciMLPublic ────────── v1.0.0
#    Installed ZygoteRules ────────── v0.2.7
#    Installed RealDot ────────────── v0.1.0
#    Installed Functors ───────────── v0.5.2
#    Installed Optimisers ─────────── v0.4.6
#    Installed IRTools ────────────── v0.4.15
#    Installed JLD2 ───────────────── v0.5.15
#    Installed NaNMath ────────────── v1.1.3
#    Installed MLJFlux ────────────── v0.6.6
#    Installed ProgressLogging ────── v0.1.5
#    Installed Metalhead ──────────── v0.9.5
#    Installed MLDataDevices ──────── v1.15.0
#    Installed OneHotArrays ───────── v0.2.10
#    Installed ChainRules ─────────── v1.72.6
#    Installed Zygote ─────────────── v0.7.10
#    Installed CommonSubexpressions ─ v0.3.1
#    Installed DiffRules ──────────── v1.15.1
#    Installed DiffResults ────────── v1.1.0
#    Installed EnzymeCore ─────────── v0.8.16
#    Installed PartialFunctions ───── v1.2.1
#    Installed SparseInverseSubset ── v0.1.2
#    Installed StructArrays ───────── v0.7.2
#    Installed Flux ───────────────── v0.16.5
#    Installed ForwardDiff ────────── v1.3.0
#    Installed BSON ───────────────── v0.3.9
#     Updating `~/.julia/environments/v1.11/Project.toml`
# ⌃ [094fc8d1] + MLJFlux v0.6.6
#     Updating `~/.julia/environments/v1.11/Manifest.toml`
#   [fbb218c0] + BSON v0.3.9
#   [082447d4] + ChainRules v1.72.6
#   [bbf7d656] + CommonSubexpressions v0.3.1
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.15.1
#   [f151be2c] + EnzymeCore v0.8.16
#   [587475ba] + Flux v0.16.5
#   [f6369f11] + ForwardDiff v1.3.0
#   [d9f16b24] + Functors v0.5.2
#   [7869d1d1] + IRTools v0.4.15
# ⌅ [033835bb] + JLD2 v0.5.15
#   [7e8f7934] + MLDataDevices v1.15.0
# ⌃ [094fc8d1] + MLJFlux v0.6.6
#   [dbeba491] + Metalhead v0.9.5
#   [77ba4419] + NaNMath v1.1.3
#   [0b1bfda6] + OneHotArrays v0.2.10
#   [3bd65402] + Optimisers v0.4.6
#   [570af359] + PartialFunctions v1.2.1
#   [33c8b6b6] + ProgressLogging v0.1.5
#   [c1ae055f] + RealDot v0.1.0
#   [431bcebd] + SciMLPublic v1.0.0
#   [dc90abb0] + SparseInverseSubset v0.1.2
#   [09ab397b] + StructArrays v0.7.2
#   [e88e6eb3] + Zygote v0.7.10
#   [700de1a5] + ZygoteRules v0.2.7
#         Info Packages marked with ⌃ and ⌅ have new versions available. Those with ⌃ may be upgradable, but those with ⌅ are restricted by compatibility constraints from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#     428.5 ms  ✓ RealDot
#     374.3 ms  ✓ SciMLPublic
#     377.9 ms  ✓ NaNMath
#     375.4 ms  ✓ ProgressLogging
#     373.9 ms  ✓ CommonSubexpressions
#     373.3 ms  ✓ PartialFunctions
#     383.5 ms  ✓ SparseInverseSubset
#     402.6 ms  ✓ BSON
#     404.4 ms  ✓ EnzymeCore
#     254.6 ms  ✓ DiffResults
#     382.5 ms  ✓ Functors
#     386.1 ms  ✓ ZygoteRules
#     386.2 ms  ✓ DiffRules
#     395.1 ms  ✓ EnzymeCore → AdaptExt
#     440.9 ms  ✓ StructArrays
#     589.5 ms  ✓ OneHotArrays
#     447.8 ms  ✓ KernelAbstractions → EnzymeExt
#     829.3 ms  ✓ IRTools
#     496.9 ms  ✓ NNlib → NNlibEnzymeCoreExt
#     537.6 ms  ✓ StructArrays → StructArraysAdaptExt
#     482.3 ms  ✓ StructArrays → StructArraysSparseArraysExt
#     719.5 ms  ✓ Optimisers
#     260.9 ms  ✓ StructArrays → StructArraysLinearAlgebraExt
#     457.0 ms  ✓ StructArrays → StructArraysStaticArraysExt
#     907.8 ms  ✓ MLDataDevices
#     469.0 ms  ✓ StructArrays → StructArraysGPUArraysCoreExt
#     324.6 ms  ✓ Accessors → StructArraysExt
#     308.1 ms  ✓ BangBang → BangBangStructArraysExt
#     385.3 ms  ✓ Optimisers → OptimisersEnzymeCoreExt
#     373.2 ms  ✓ Optimisers → OptimisersAdaptExt
#     534.3 ms  ✓ MLDataDevices → MLDataDevicesFillArraysExt
#     578.6 ms  ✓ MLDataDevices → MLDataDevicesChainRulesCoreExt
#     531.3 ms  ✓ MLDataDevices → MLDataDevicesSparseArraysExt
#     923.1 ms  ✓ MLDataDevices → MLDataDevicesOneHotArraysExt
#     821.6 ms  ✓ MLDataDevices → MLDataDevicesMLUtilsExt
#    2455.0 ms  ✓ ForwardDiff
#     571.2 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#     605.1 ms  ✓ NNlib → NNlibForwardDiffExt
#    3435.1 ms  ✓ ChainRules
#     484.2 ms  ✓ MLDataDevices → MLDataDevicesChainRulesExt
#   10901.6 ms  ✓ JLD2
#     809.9 ms  ✓ JLD2 → UnPackExt
#   11726.0 ms  ✓ Zygote
#     844.7 ms  ✓ MLDataDevices → MLDataDevicesZygoteExt
#    1154.0 ms  ✓ Zygote → ZygoteDistancesExt
#    4951.4 ms  ✓ Flux
#    2980.1 ms  ✓ Metalhead
#    3217.1 ms  ✓ MLJFlux
#   48 dependencies successfully precompiled in 29 seconds. 275 already precompiled.
#    Resolving package versions...
#     Updating `~/.julia/environments/v1.11/Project.toml`
#   [587475ba] + Flux v0.16.5
#   No Changes to `~/.julia/environments/v1.11/Manifest.toml`

# %%
using CSV, DataFrames, StatsModels, GLM, Random, RData, MLBase, MLJ, PrettyTables, FixedEffectModels
using MLDataUtils, FixedEffectModels, DecisionTree, Lasso, GLMNet, MLJScikitLearnInterface

# %%
using Downloads, CSV, DataFrames

# URL de tu dataset
url = "https://raw.githubusercontent.com/VC2015/DMLonGitHub/master/penn_jae.dat"
Downloads.download(url, "penn_jae.dat")
# Leer el archivo (delimitado por espacios)
data = CSV.read("penn_jae.dat", DataFrame; delim=' ', ignorerepeated=true)

# Mostrar información básica
println("Número de filas: ", size(data, 1))
println("Número de columnas: ", size(data, 2))
println("Nombres de columnas:")
println(names(data))

first(data, 5)
# Out:
# Número de filas: 13913
# Número de columnas: 23
# Nombres de columnas:
# ["abdt", "tg", "inuidur1", "inuidur2", "female", "black", "hispanic", "othrace", "dep", "q1", "q2", "q3", "q4", "q5", "q6", "recall", "agelt35", "agegt54", "durable", "nondurable", "lusd", "husd", "muld"]
# 5×23 DataFrame
#  Row │ abdt   tg     inuidur1  inuidur2  female  black  hispanic  othrace  dep ⋯
#      │ Int64  Int64  Int64     Int64     Int64   Int64  Int64     Int64    Int ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 10824      0        18        18       0      0         0        0      ⋯
#    2 │ 10635      2         7         3       0      0         0        0
#    3 │ 10551      5        18         6       1      0         0        0
#    4 │ 10824      0         1         1       0      0         0        0
#    5 │ 10747      0        27        27       0      0         0        0      ⋯
#                                                               15 columns omitted

# %%
# Cleaning and set-up
filter!(row -> row.tg == 0 || row.tg == 4, data)
data.T4 = [row.tg == 4 ? 1 : 0 for row in eachrow(data)]
filter!(row -> row.inuidur1 > 0, data)
data.y = log.(data.inuidur1)
data.dep_0 = [row.dep == 0 ? 1 : 0 for row in eachrow(data)]
data.dep_1 = [row.dep == 1 ? 1 : 0 for row in eachrow(data)]
data.dep_2 = [row.dep == 2 ? 1 : 0 for row in eachrow(data)]

xvars = [
    :female, :black, :othrace,
    :dep_1, :dep_2,
    :q2, :q3, :q4, :q5, :q6,
    :recall, :agelt35, :agegt54,
    :durable, :nondurable, :lusd, :husd
]

# Definir Y, D y X para la estimación
y = data.y
d = data.T4
x = data[:, xvars]

println("\nVariables listas para DML:")
println("Outcome (Y): log(inuidur1)")
println("Treatment (D): T4 (tg==4)")
println("Número de controles (X): ", length(xvars))
println("Dimensiones de X: ", size(x))

# Vista rápida de los datos
first(data, 5)
# Out:
# Variables listas para DML:
# Outcome (Y): log(inuidur1)
# Treatment (D): T4 (tg==4)
# Número de controles (X): 17
# Dimensiones de X: (5099, 17)
# 5×28 DataFrame
#  Row │ abdt   tg     inuidur1  inuidur2  female  black  hispanic  othrace  dep ⋯
#      │ Int64  Int64  Int64     Int64     Int64   Int64  Int64     Int64    Int ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 10824      0        18        18       0      0         0        0      ⋯
#    2 │ 10824      0         1         1       0      0         0        0
#    3 │ 10747      0        27        27       0      0         0        0
#    4 │ 10607      4         9         9       0      0         0        0
#    5 │ 10831      0        27        27       0      0         0        0      ⋯
#                                                               20 columns omitted

# %%
function training_sample_append(cv_split, test_sample_index)
        training_indices = []
        for vector in cv_split[Not(test_sample_index)]
                training_indices = [training_indices; vector]
        end
        return training_indices, cv_split[test_sample_index]
end

function dml(x, d, y, dreg, yreg, nfold)
        n = length(y)
        cv = [partition(eachindex(y), fill(1/nfold, nfold-1)..., shuffle = true, rng = 1234)...]
        machine_y = machine(yreg, x, y, scitype_check_level=0)
        machine_d = machine(dreg, x, d, scitype_check_level=0)
        y_hat = zeros(n)
        d_hat = zeros(n)

        for fold in 1:nfold
                training_fold, test_fold = training_sample_append(cv, fold)
                y_hat[test_fold] = MLJ.predict(MLJ.fit!(machine_y, rows = training_fold), x[test_fold, :])
                d_hat[test_fold] = MLJ.predict(MLJ.fit!(machine_d, rows = training_fold), x[test_fold, :])
        end

        resy = y .- y_hat
        resd = reshape(d .- d_hat, (n, 1))
        estimate = lm(resd, resy)
        coef_est = GLM.coef(estimate)[1]
        se = GLM.coeftable(estimate).cols[2][1]
        println(" coef (se) = ", coef_est ,"(",se,")")
        return coef_est, se, resy, resd;
end

function summarize(point, stderr, resy, resd, name)
        return DataFrame(
                model = [name],
                estimate = [point], stderr = [stderr], 
                rmse_y = [sqrt(mean(resy .^ 2))], 
                rmse_d = [sqrt(mean(resd .^ 2))]
        )
end
# Out:
# summarize (generic function with 1 method)

# %%
LinearRegressor = @load LinearRegressor pkg=MLJScikitLearnInterface verbosity=0
dreg = Standardizer() |> LinearRegressor()
yreg = Standardizer() |> LinearRegressor()
result_ols = dml(x, d, y, dreg, yreg, 10)
table_ols = summarize(result_ols..., "OLS")

LassoCVRegressor = @load LassoCVRegressor pkg=MLJScikitLearnInterface verbosity=0
dreg = Standardizer() |> LassoCVRegressor(max_iter=200000)
yreg = Standardizer() |> LassoCVRegressor(max_iter=200000)
results_lasso = dml(x, d, y, dreg, yreg, 10)
table_lasso = summarize(results_lasso..., "LassoCV")

RandomForestRegressor = @load RandomForestRegressor pkg=MLJScikitLearnInterface verbosity=0
dreg = RandomForestRegressor()
yreg = RandomForestRegressor()
results_rf = dml(x, d, y, dreg, yreg, 10)
table_rf = summarize(results_rf..., "RF")

dreg = Standardizer() |> LassoCVRegressor(max_iter=200000)
results_mix = dml(x, d, y, dreg , yreg, 10)
table_mix = summarize(results_mix..., "RF/LassoCV")

NeuralNetworkRegressor = @load NeuralNetworkRegressor pkg=MLJFlux verbosity=0 
nn_model = NeuralNetworkRegressor(
    builder = MLJFlux.MLP(; hidden=(20,20), σ=relu), 
    epochs = 100,
    batch_size = 32,
    optimiser = Flux.ADAM(0.001),
    rng = 1234
)
dreg = Standardizer() |> nn_model
yreg = Standardizer() |> nn_model
results_nn = dml(x, d, y, dreg, yreg, 10)
table_nn = summarize(results_nn..., "NeuralNet")
# Out:
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
#  coef (se) = -0.06980700224406336
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:linear_regressor, …).
# (0.03522987047951291)
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
#  coef (se) = -0.07297073580257903(0.035281673581847965)
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
#  coef (se) = -0.1022458661062878(0.034858329213297366)
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(RandomForestRegressor(n_estimators = 100, …), …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
#  coef (se) = -0.09068804606958437(0.03737404519272649)
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:lasso_cv_regressor, …).
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:06
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
# [ Info: Training machine(DeterministicPipeline(standardizer = Standardizer(features = Symbol[], …), …), …).
# [ Info: Training machine(:standardizer, …).
# ┌ Warning: No features to standarize.
# └ @ MLJModels ~/.julia/packages/MLJModels/ziReN/src/builtins/Transformers.jl:637
# [ Info: Training machine(:neural_network_regressor, …).
# [ Info: MLJFlux: converting input data to Float32
# Optimising neural net: 100%[=========================] Time: 0:00:00
#  coef (se) = -0.07574458421704361(0.03458495423037937)
# 1×5 DataFrame
#  Row │ model      estimate    stderr    rmse_y   rmse_d
#      │ String     Float64     Float64   Float64  Float64
# ─────┼────────────────────────────────────────────────────
#    1 │ NeuralNet  -0.0757446  0.034585  1.21663  0.492455

# %%
pretty_table([table_ols; table_lasso; table_rf; table_mix; table_nn])
# Out:
# ┌────────────┬────────────┬───────────┬─────────┬──────────┐
# │      model │   estimate │    stderr │  rmse_y │   rmse_d │
# │     String │    Float64 │   Float64 │ Float64 │  Float64 │
# ├────────────┼────────────┼───────────┼─────────┼──────────┤
# │        OLS │  -0.069807 │ 0.0352299 │ 1.19593 │ 0.475255 │
# │    LassoCV │ -0.0729707 │ 0.0352817 │ 1.19601 │ 0.474574 │
# │         RF │  -0.102246 │ 0.0348583 │ 1.26704 │ 0.508647 │
# │ RF/LassoCV │  -0.090688 │  0.037374 │ 1.26714 │ 0.474574 │
# │  NeuralNet │ -0.0757446 │  0.034585 │ 1.21663 │ 0.492455 │
# └────────────┴────────────┴───────────┴─────────┴──────────┘

# %%
vcat(table_ols, table_lasso, table_rf, table_mix, table_nn)
# Out:
# 5×5 DataFrame
#  Row │ model       estimate    stderr     rmse_y   rmse_d
#      │ String      Float64     Float64    Float64  Float64
# ─────┼──────────────────────────────────────────────────────
#    1 │ OLS         -0.069807   0.0352299  1.19593  0.475255
#    2 │ LassoCV     -0.0729707  0.0352817  1.19601  0.474574
#    3 │ RF          -0.102246   0.0348583  1.26704  0.508647
#    4 │ RF/LassoCV  -0.090688   0.037374   1.26714  0.474574
#    5 │ NeuralNet   -0.0757446  0.034585   1.21663  0.492455
